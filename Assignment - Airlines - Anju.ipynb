# %% [markdown]
# Assignment 2
#
# By FNU ANJU ANN PAUL
#
# Topic: Airlines

# %% [markdown]
# Here is the link to the Dataset

# %%
import airlines
airports = airlines.get_airports()

# %%
type(airports)
# Out:
# list

# %% [markdown]
# airports is list type

# %%
len(airports)
# Out:
# 4408

# %% [markdown]
# length of the airport is 4408

# %%
airports[0]
# Out:
# {'Airport': {'Code': 'ATL',
#   'Name': 'Atlanta, GA: Hartsfield-Jackson Atlanta International'},
#  'Time': {'Label': '2003/06', 'Month': 6, 'Month Name': 'June', 'Year': 2003},
#  'Statistics': {'# of Delays': {'Carrier': 1009,
#    'Late Aircraft': 1275,
#    'National Aviation System': 3217,
#    'Security': 17,
#    'Weather': 328},
#   'Carriers': {'Names': 'American Airlines Inc.,JetBlue Airways,Continental Air Lines Inc.,Delta Air Lines Inc.,Atlantic Southeast Airlines,AirTran Airways Corporation,America West Airlines Inc.,Northwest Airlines Inc.,ExpressJet Airlines Inc.,United Air Lines Inc.,US Airways Inc.',
#    'Total': 11},
#   'Flights': {'Cancelled': 216,
#    'Delayed': 5843,
#    'Diverted': 27,
#    'On Time': 23974,
#    'Total': 30060},
#   'Minutes Delayed': {'Carrier': 61606,
#    'Late Aircraft': 68335,
#    'National Aviation System': 118831,
#    'Security': 518,
#    'Total': 268764,
#    'Weather': 19474}}}

# %%
type(airports[0])
# Out:
# dict

# %% [markdown]
# We have dictionary inside list airports

# %%
airports[0]['Airport']['Name']
# Out:
# 'Atlanta, GA: Hartsfield-Jackson Atlanta International'

# %% [markdown]
# First Airport name is Atlanta, GA: Hartsfield- Jackson Atlanta International which is in 0th position

# %%
type(airports[0]['Airport']['Name'])
# Out:
# str

# %% [markdown]
# Airport Name is a string value

# %%
airports[0]['Statistics']
# Out:
# {'# of Delays': {'Carrier': 1009,
#   'Late Aircraft': 1275,
#   'National Aviation System': 3217,
#   'Security': 17,
#   'Weather': 328},
#  'Carriers': {'Names': 'American Airlines Inc.,JetBlue Airways,Continental Air Lines Inc.,Delta Air Lines Inc.,Atlantic Southeast Airlines,AirTran Airways Corporation,America West Airlines Inc.,Northwest Airlines Inc.,ExpressJet Airlines Inc.,United Air Lines Inc.,US Airways Inc.',
#   'Total': 11},
#  'Flights': {'Cancelled': 216,
#   'Delayed': 5843,
#   'Diverted': 27,
#   'On Time': 23974,
#   'Total': 30060},
#  'Minutes Delayed': {'Carrier': 61606,
#   'Late Aircraft': 68335,
#   'National Aviation System': 118831,
#   'Security': 518,
#   'Total': 268764,
#   'Weather': 19474}}

# %%
airports[0]['Statistics']['Flights']
# Out:
# {'Cancelled': 216,
#  'Delayed': 5843,
#  'Diverted': 27,
#  'On Time': 23974,
#  'Total': 30060}

# %%
airports[0]['Statistics']['Flights']['Delayed']
# Out:
# 5843

# %%
airports[1]['Statistics']['Flights']['Delayed']
# Out:
# 1623

# %%
for i in airports:
    print('Airport Name: ' + i['Airport']['Name'] + ' No. of Ontime Flights: ' + str(i['Statistics']['Flights']['On Time']))
# Out:
# Airport Name: Atlanta, GA: Hartsfield-Jackson Atlanta International No. of Ontime Flights: 23974
# Airport Name: Boston, MA: Logan International No. of Ontime Flights: 7875
# Airport Name: Baltimore, MD: Baltimore/Washington International Thurgood Marshall No. of Ontime Flights: 6998
# Airport Name: Charlotte, NC: Charlotte Douglas International No. of Ontime Flights: 7021
# Airport Name: Washington, DC: Ronald Reagan Washington National No. of Ontime Flights: 5321
# Airport Name: Denver, CO: Denver International No. of Ontime Flights: 10024
# Airport Name: Dallas/Fort Worth, TX: Dallas/Fort Worth International No. of Ontime Flights: 22303
# Airport Name: Detroit, MI: Detroit Metro Wayne County No. of Ontime Flights: 10227
# Airport Name: Newark, NJ: Newark Liberty International No. of Ontime Flights: 9441
# Airport Name: Fort Lauderdale, FL: Fort Lauderdale-Hollywood International No. of Ontime Flights: 3672
# ...

# %% [markdown]
# The above gives Airport Name and its corresponding On time Flights

# %%
for i in airports:
    if(str(i['Time']['Year'])=='2003'):
        S = i['Statistics']['Minutes Delayed']['Security']
        if S > 0:
            print(i['Airport']['Name'] + ' had Security related delays in ' + str(i['Time']['Year']))
# Out:
# Atlanta, GA: Hartsfield-Jackson Atlanta International had Security related delays in 2003
# Boston, MA: Logan International had Security related delays in 2003
# Baltimore, MD: Baltimore/Washington International Thurgood Marshall had Security related delays in 2003
# Charlotte, NC: Charlotte Douglas International had Security related delays in 2003
# Washington, DC: Ronald Reagan Washington National had Security related delays in 2003
# Denver, CO: Denver International had Security related delays in 2003
# Dallas/Fort Worth, TX: Dallas/Fort Worth International had Security related delays in 2003
# Detroit, MI: Detroit Metro Wayne County had Security related delays in 2003
# Newark, NJ: Newark Liberty International had Security related delays in 2003
# Fort Lauderdale, FL: Fort Lauderdale-Hollywood International had Security related delays in 2003
# Washington, DC: Washington Dulles International had Security related delays in 2003
# ...

# %% [markdown]
# The above gives Airports with security delays in 2003

# %%
import Airportmodule as apmod

# %% [markdown]
# Importing Airport module

# %%
dir(apmod)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'ontimepercentage']

# %%
apmod.ontimepercentage(airports,2003)
# Out:
# Percentage of ontime flights in 2003
# Atlanta, GA: Hartsfield-Jackson Atlanta International     :79.75%
# Boston, MA: Logan International     :81.70%
# Baltimore, MD: Baltimore/Washington International Thurgood Marshall     :84.45%
# Charlotte, NC: Charlotte Douglas International     :80.98%
# Washington, DC: Ronald Reagan Washington National     :81.70%
# Denver, CO: Denver International     :85.74%
# Dallas/Fort Worth, TX: Dallas/Fort Worth International     :80.73%
# Detroit, MI: Detroit Metro Wayne County     :87.01%
# Newark, NJ: Newark Liberty International     :75.49%
# Fort Lauderdale, FL: Fort Lauderdale-Hollywood International     :78.76%
# Washington, DC: Washington Dulles International     :83.47%
# Houston, TX: George Bush Intercontinental/Houston     :81.58%
# New York, NY: John F. Kennedy International     :81.26%
# Las Vegas, NV: McCarran International     :83.52%
# Los Angeles, CA: Los Angeles International     :85.47%
# New York, NY: LaGuardia     :80.39%
# ...

# %% [markdown]
# The above gives percentage of on time flights in 2003

# %%
apmod.ontimepercentage(airports,2004)
# Out:
# Percentage of ontime flights in 2004
# Atlanta, GA: Hartsfield-Jackson Atlanta International     :75.04%
# Boston, MA: Logan International     :76.81%
# Baltimore, MD: Baltimore/Washington International Thurgood Marshall     :79.65%
# Charlotte, NC: Charlotte Douglas International     :81.88%
# Washington, DC: Ronald Reagan Washington National     :78.56%
# Denver, CO: Denver International     :77.69%
# Dallas/Fort Worth, TX: Dallas/Fort Worth International     :78.37%
# Detroit, MI: Detroit Metro Wayne County     :75.48%
# Newark, NJ: Newark Liberty International     :72.62%
# Fort Lauderdale, FL: Fort Lauderdale-Hollywood International     :74.64%
# Washington, DC: Washington Dulles International     :80.35%
# Houston, TX: George Bush Intercontinental/Houston     :82.98%
# New York, NY: John F. Kennedy International     :74.36%
# Las Vegas, NV: McCarran International     :78.10%
# Los Angeles, CA: Los Angeles International     :81.02%
# New York, NY: LaGuardia     :68.62%
# ...

# %% [markdown]
# The above gives percentage of on time flights in 2004
